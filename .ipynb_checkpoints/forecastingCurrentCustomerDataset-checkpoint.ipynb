# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
with open('Generated/model.pkl',mode='rb') as fid:
    logreg_model = pickle.load(fid)
    print(logreg_model)

current_score_df = pd.read_csv('current_groupscore.csv', index_col=[0,1])
current_score_df.shape
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')
# (11897, 8)

# %%
current_score_df.to_numpy().shape
# Out:
# (11897, 8)

# %%
predictions = logreg_model.predict_proba(current_score_df.to_numpy())
predictions
logreg_model.classes_
# Out:
# /home/alejandro-armenta/Documents/churn/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([False,  True])

# %%
predict_df = pd.DataFrame(predictions, 
             columns=['churn_prob','retention_prob'], 
             index=current_score_df.index)

# %%
predict_df.to_csv('current_predictions.csv', header=True)

# %%
plt.figure(figsize=(6,4))
n, bins, _ = plt.hist(predict_df['churn_prob'].values, bins=20, color="black")
plt.xlabel('churn probabilty')
plt.ylabel('# of customers')
plt.title('Histogram of active customer churn probability')
plt.grid()
plt.savefig('churn_hist.png',format='png')
plt.close()

# %%
len(n)
bins
# Out:
# array([0.00050904, 0.01878063, 0.03705222, 0.05532382, 0.07359541,
#        0.091867  , 0.11013859, 0.12841018, 0.14668177, 0.16495337,
#        0.18322496, 0.20149655, 0.21976814, 0.23803973, 0.25631132,
#        0.27458292, 0.29285451, 0.3111261 , 0.32939769, 0.34766928,
#        0.36594087])

# %%
#esta tomando el lado derecho de los bins como marca 
hist_df = pd.DataFrame(
    {
        'n':n,
        'bins':bins[1:],
    }
)

# %%
hist_df.to_csv('current_churnhist.csv', header=True)
