# %%
# %load_ext sql
# %sql postgresql://postgres:postgres@localhost/churn
# Out:
# Connecting to 'postgresql://postgres:***@localhost/churn'

# %%
# %sql set search_path to socialnet7;
# Out:
# Running query in 'postgresql://postgres:***@localhost/churn'
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT
#   *
# FROM
#   metric_name
# Out:
# Running query in 'postgresql://postgres:***@localhost/churn'
# 21 rows affected.
# +----------------+---------------------+
# | metric_name_id |     metric_name     |
# +----------------+---------------------+
# |       0        |    like_per_month   |
# |       1        | newfriend_per_month |
# |       2        |    post_per_month   |
# |       3        |   adview_per_month  |
# |       4        |  dislike_per_month  |
# |       5        |  unfriend_per_month |
# |       6        |  message_per_month  |
# |       7        |   reply_per_month   |
# |       8        |    account_tenure   |
# |       21       |    adviw_per_post   |
# +----------------+---------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SET
#   search_path TO socialnet7;
#
# WITH
#   metric_date AS (
#     SELECT
#       MAX(metric_time) AS last_metric_time
#     FROM
#       metric
#   )
# SELECT
#   account_id, metric_value as account_tenure
# FROM
#   metric
#   INNER JOIN metric_date ON metric_time = last_metric_time
# WHERE
#   metric_name_id = 8 --account tenure
#   AND metric_value >= 14
# Out:
# Running query in 'postgresql://postgres:***@localhost/churn'
# 11897 rows affected.
# +------------+----------------+
# | account_id | account_tenure |
# +------------+----------------+
# |     0      |     101.0      |
# |     1      |     113.0      |
# |     2      |     129.0      |
# |     4      |     122.0      |
# |     6      |     105.0      |
# |     7      |     113.0      |
# |     9      |     107.0      |
# |     10     |     111.0      |
# |     12     |     109.0      |
# |     13     |     100.0      |
# +------------+----------------+
# Truncated to displaylimit of 10.

# %%
11897
# Out:
# 11897
