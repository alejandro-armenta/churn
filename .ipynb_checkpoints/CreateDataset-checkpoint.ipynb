# %%
import pandas as pd
from sqlalchemy import create_engine

DB_USER = 'postgres'
DB_PASSWORD = 'postgres'
DB_HOST = 'localhost'
DB_PORT = '5432'
DB_NAME = 'churn'

database_url = f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
database_url
# Out:
# 'postgresql+psycopg2://postgres:postgres@localhost:5432/churn'

# %%
sql_query = """set search_path to socialnet7;

with observation_params as (
select  
    interval '7 day' as metric_period,
    '2020-03-01'::timestamp as obs_start,
    '2020-05-10'::timestamp as obs_end
    )
select 
    --esta metrica es un churn si o no
    --esta metrica esta dentro del rango de fechas si o no
    
    m.account_id, observation_date, is_churn,
    --sum(case when metric_name_id = 0 then metric_value else 0 end) as like_per_month,
    --sum(case when metric_name_id = 1 then metric_value else 0 end) as newfriend_per_month

    SUM(
    CASE
      WHEN metric_name_id = 0 THEN metric_value
      ELSE 0
    END
  ) AS like_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 1 THEN metric_value
      ELSE 0
    END
  ) AS newfriend_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 2 THEN metric_value
      ELSE 0
    END
  ) AS post_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 3 THEN metric_value
      ELSE 0
    END
  ) AS adview_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 4 THEN metric_value
      ELSE 0
    END
  ) AS dislike_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 33 THEN metric_value
      ELSE 0
    END
  ) AS unfriend_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 6 THEN metric_value
      ELSE 0
    END
  ) AS message_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 7 THEN metric_value
      ELSE 0
    END
  ) AS reply_per_month,
  SUM(
    CASE
      WHEN metric_name_id = 21 THEN metric_value
      ELSE 0
    END
  ) AS adview_per_post,
  SUM(
    CASE
      WHEN metric_name_id = 22 THEN metric_value
      ELSE 0
    END
  ) AS reply_per_message,
  SUM(
    CASE
      WHEN metric_name_id = 23 THEN metric_value
      ELSE 0
    END
  ) AS like_per_post,
  SUM(
    CASE
      WHEN metric_name_id = 24 THEN metric_value
      ELSE 0
    END
  ) AS post_per_message,
  SUM(
    CASE
      WHEN metric_name_id = 28 THEN metric_value
      ELSE 0
    END
  ) AS unfriend_per_newfriend,
  SUM(
    CASE
      WHEN metric_name_id = 27 THEN metric_value
      ELSE 0
    END
  ) AS dislike_pcnt,
  SUM(
    CASE
      WHEN metric_name_id = 30 THEN metric_value
      ELSE 0
    END
  ) AS newfriend_pcnt_chng,
  SUM(
    CASE
      WHEN metric_name_id = 31 THEN metric_value
      ELSE 0
    END
  ) AS days_since_newfriend
    
    --observation_date
    --count(m.account_id)
    
    from metric m 
    inner join observation_params on metric_time BETWEEN obs_start and obs_end
    inner join observation o on m.account_id = o.account_id 
    and m.metric_time > (o.observation_date - metric_period)::timestamp 
    and m.metric_time <= o.observation_date::timestamp
group by m.account_id, m.metric_time, observation_date, is_churn
order by observation_date, m.account_id"""

sql_query
# Out:
# "set search_path to socialnet7;\n\nwith observation_params as (\nselect  \n    interval '7 day' as metric_period,\n    '2020-03-01'::timestamp as obs_start,\n    '2020-05-10'::timestamp as obs_end\n    )\nselect \n    --esta metrica es un churn si o no\n    --esta metrica esta dentro del rango de fechas si o no\n\n    m.account_id, observation_date, is_churn,\n    --sum(case when metric_name_id = 0 then metric_value else 0 end) as like_per_month,\n    --sum(case when metric_name_id = 1 then metric_value else 0 end) as newfriend_per_month\n\n    SUM(\n    CASE\n      WHEN metric_name_id = 0 THEN metric_value\n      ELSE 0\n    END\n  ) AS like_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 1 THEN metric_value\n      ELSE 0\n    END\n  ) AS newfriend_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 2 THEN metric_value\n      ELSE 0\n    END\n  ) AS post_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 3 THEN metric_value\n      ELSE 0\n    END\n  ) AS adview_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 4 THEN metric_value\n      ELSE 0\n    END\n  ) AS dislike_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 33 THEN metric_value\n      ELSE 0\n    END\n  ) AS unfriend_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 6 THEN metric_value\n      ELSE 0\n    END\n  ) AS message_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 7 THEN metric_value\n      ELSE 0\n    END\n  ) AS reply_per_month,\n  SUM(\n    CASE\n      WHEN metric_name_id = 21 THEN metric_value\n      ELSE 0\n    END\n  ) AS adview_per_post,\n  SUM(\n    CASE\n      WHEN metric_name_id = 22 THEN metric_value\n      ELSE 0\n    END\n  ) AS reply_per_message,\n  SUM(\n    CASE\n      WHEN metric_name_id = 23 THEN metric_value\n      ELSE 0\n    END\n  ) AS like_per_post,\n  SUM(\n    CASE\n      WHEN metric_name_id = 24 THEN metric_value\n      ELSE 0\n    END\n  ) AS post_per_message,\n  SUM(\n    CASE\n      WHEN metric_name_id = 28 THEN metric_value\n      ELSE 0\n    END\n  ) AS unfriend_per_newfriend,\n  SUM(\n    CASE\n      WHEN metric_name_id = 27 THEN metric_value\n      ELSE 0\n    END\n  ) AS dislike_pcnt,\n  SUM(\n    CASE\n      WHEN metric_name_id = 30 THEN metric_value\n      ELSE 0\n    END\n  ) AS newfriend_pcnt_chng,\n  SUM(\n    CASE\n      WHEN metric_name_id = 31 THEN metric_value\n      ELSE 0\n    END\n  ) AS days_since_newfriend\n\n    --observation_date\n    --count(m.account_id)\n\n    from metric m \n    inner join observation_params on metric_time BETWEEN obs_start and obs_end\n    inner join observation o on m.account_id = o.account_id \n    and m.metric_time > (o.observation_date - metric_period)::timestamp \n    and m.metric_time <= o.observation_date::timestamp\ngroup by m.account_id, m.metric_time, observation_date, is_churn\norder by observation_date, m.account_id"

# %%
engine = create_engine(database_url)
connection = engine.connect()
connection

# %%
df = pd.read_sql(sql_query,connection, index_col=['account_id','observation_date'])
df.to_csv('original.csv',header=True)

# %%
df
# Out:
#                              is_churn  like_per_month  newfriend_per_month  \
# account_id observation_date
# 27         2020-03-01           False            28.0                  5.0
# 51         2020-03-01           False            26.0                  5.0
# 95         2020-03-01           False            74.0                  5.0
# 123        2020-03-01           False            28.0                  6.0
# 189        2020-03-01            True             3.0                  1.0
# ...                               ...             ...                  ...
# 13132      2020-05-10           False            19.0                  0.0
# 13141      2020-05-10           False             3.0                  1.0
# 13155      2020-05-10           False             2.0                  0.0
# 13171      2020-05-10           False            15.0                  6.0
# 13248      2020-05-10           False           439.0                 50.0
#
#                              post_per_month  adview_per_month  \
# account_id observation_date
# 27         2020-03-01                  14.0              33.0
# 51         2020-03-01                   4.0              19.0
# 95         2020-03-01                  64.0              17.0
# 123        2020-03-01                  13.0               4.0
# 189        2020-03-01                   8.0              16.0
# ...                                     ...               ...
# 13132      2020-05-10                  20.0               2.0
# 13141      2020-05-10                   6.0               9.0
# 13155      2020-05-10                   1.0               1.0
# 13171      2020-05-10                  44.0              16.0
# 13248      2020-05-10                 276.0             664.0
#
#                              dislike_per_month  unfriend_per_month  \
# account_id observation_date
# 27         2020-03-01                      2.0            0.333333
# 51         2020-03-01                      4.0            0.666667
# 95         2020-03-01                     20.0            0.000000
# 123        2020-03-01                     25.0            0.000000
# 189        2020-03-01                      2.0            0.000000
# ...                                        ...                 ...
# 13132      2020-05-10                      3.0            0.000000
# 13141      2020-05-10                      1.0            0.000000
# 13155      2020-05-10                      1.0            0.000000
# 13171      2020-05-10                      1.0            0.000000
# 13248      2020-05-10                     44.0            0.333333
#
#                              message_per_month  reply_per_month  \
# account_id observation_date
# 27         2020-03-01                      1.0              0.0
# 51         2020-03-01                     42.0             28.0
# 95         2020-03-01                     12.0              6.0
# 123        2020-03-01                     11.0              1.0
# 189        2020-03-01                      0.0              0.0
# ...                                        ...              ...
# 13132      2020-05-10                     27.0              6.0
# 13141      2020-05-10                     13.0              5.0
# 13155      2020-05-10                     27.0             17.0
# 13171      2020-05-10                     26.0              6.0
# 13248      2020-05-10                    448.0             50.0
#
#                              adview_per_post  reply_per_message  \
# account_id observation_date
# 27         2020-03-01               2.357143           0.000000
# 51         2020-03-01               4.750000           0.666667
# 95         2020-03-01               0.265625           0.500000
# 123        2020-03-01               0.307692           0.090909
# 189        2020-03-01               2.000000           0.000000
# ...                                      ...                ...
# 13132      2020-05-10               0.100000           0.222222
# 13141      2020-05-10               1.500000           0.384615
# 13155      2020-05-10               1.000000           0.629630
# 13171      2020-05-10               0.363636           0.230769
# 13248      2020-05-10               2.405797           0.111607
#
#                              like_per_post  post_per_message  \
# account_id observation_date
# 27         2020-03-01             2.000000         14.000000
# 51         2020-03-01             6.500000          0.095238
# 95         2020-03-01             1.156250          5.333334
# 123        2020-03-01             2.153846          1.181818
# 189        2020-03-01             0.375000          0.000000
# ...                                    ...               ...
# 13132      2020-05-10             0.950000          0.740741
# 13141      2020-05-10             0.500000          0.461538
# 13155      2020-05-10             2.000000          0.037037
# 13171      2020-05-10             0.340909          1.692308
# 13248      2020-05-10             1.590580          0.616071
#
#                              unfriend_per_newfriend  dislike_pcnt  \
# account_id observation_date
# 27         2020-03-01                      0.101818      0.066667
# 51         2020-03-01                      0.203636      0.133333
# 95         2020-03-01                      0.000000      0.212766
# 123        2020-03-01                      0.000000      0.471698
# 189        2020-03-01                      0.000000      0.400000
# ...                                             ...           ...
# 13132      2020-05-10                      0.000000      0.136364
# 13141      2020-05-10                      0.000000      0.250000
# 13155      2020-05-10                      0.000000      0.333333
# 13171      2020-05-10                      0.000000      0.062500
# 13248      2020-05-10                      0.022400      0.091097
#
#                              newfriend_pcnt_chng  days_since_newfriend
# account_id observation_date
# 27         2020-03-01                   4.000000                   3.0
# 51         2020-03-01                  -0.166667                   1.0
# 95         2020-03-01                   0.250000                   1.0
# 123        2020-03-01                   1.000000                   2.0
# 189        2020-03-01                   0.000000                  15.0
# ...                                          ...                   ...
# 13132      2020-05-10                   0.000000                   0.0
# 13141      2020-05-10                   0.000000                  18.0
# 13155      2020-05-10                   0.000000                   0.0
# 13171      2020-05-10                   0.000000                   6.0
# 13248      2020-05-10                   0.000000                   0.0
#
# [25806 rows x 17 columns]
