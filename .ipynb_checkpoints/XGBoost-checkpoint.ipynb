# %%
import pandas as pd
import pickle
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import make_scorer
import xgboost as xgb

from Training_Pipeline import calc_lift

# %%
xgb
# Out:
# <module 'xgboost' from '/home/alejandro-armenta/Documents/churn/venv/lib/python3.12/site-packages/xgboost/__init__.py'>

# %%
grouped_data = pd.read_csv('TestChurnComplete/original.csv',index_col=[0,1])
grouped_data

y = grouped_data['is_churn'].astype(int)

X = grouped_data.drop(['is_churn'],axis=1)

#churn rate
X
# Out:
#                              like_per_month  newfriend_per_month  \
# account_id observation_date
# 27         2020-03-01                  28.0                  5.0
# 51         2020-03-01                  26.0                  5.0
# 95         2020-03-01                  74.0                  5.0
# 123        2020-03-01                  28.0                  6.0
# 189        2020-03-01                   3.0                  1.0
# ...                                     ...                  ...
# 13132      2020-05-10                  19.0                  0.0
# 13141      2020-05-10                   3.0                  1.0
# 13155      2020-05-10                   2.0                  0.0
# 13171      2020-05-10                  15.0                  6.0
# 13248      2020-05-10                 439.0                 50.0
#
#                              post_per_month  adview_per_month  \
# account_id observation_date
# 27         2020-03-01                  14.0              33.0
# 51         2020-03-01                   4.0              19.0
# 95         2020-03-01                  64.0              17.0
# 123        2020-03-01                  13.0               4.0
# 189        2020-03-01                   8.0              16.0
# ...                                     ...               ...
# 13132      2020-05-10                  20.0               2.0
# 13141      2020-05-10                   6.0               9.0
# 13155      2020-05-10                   1.0               1.0
# 13171      2020-05-10                  44.0              16.0
# 13248      2020-05-10                 276.0             664.0
#
#                              dislike_per_month  unfriend_per_month  \
# account_id observation_date
# 27         2020-03-01                      2.0                 1.0
# 51         2020-03-01                      4.0                 1.0
# 95         2020-03-01                     20.0                 0.0
# 123        2020-03-01                     25.0                 0.0
# 189        2020-03-01                      2.0                 0.0
# ...                                        ...                 ...
# 13132      2020-05-10                      3.0                 0.0
# 13141      2020-05-10                      1.0                 0.0
# 13155      2020-05-10                      1.0                 0.0
# 13171      2020-05-10                      1.0                 0.0
# 13248      2020-05-10                     44.0                 1.0
#
#                              message_per_month  reply_per_month  \
# account_id observation_date
# 27         2020-03-01                      1.0              0.0
# 51         2020-03-01                     42.0             28.0
# 95         2020-03-01                     12.0              6.0
# 123        2020-03-01                     11.0              1.0
# 189        2020-03-01                      0.0              0.0
# ...                                        ...              ...
# 13132      2020-05-10                     27.0              6.0
# 13141      2020-05-10                     13.0              5.0
# 13155      2020-05-10                     27.0             17.0
# 13171      2020-05-10                     26.0              6.0
# 13248      2020-05-10                    448.0             50.0
#
#                              account_tenure  adview_per_post  \
# account_id observation_date
# 27         2020-03-01                  55.0         2.357143
# 51         2020-03-01                  55.0         4.750000
# 95         2020-03-01                  55.0         0.265625
# 123        2020-03-01                  55.0         0.307692
# 189        2020-03-01                  55.0         2.000000
# ...                                     ...              ...
# 13132      2020-05-10                  25.0         0.100000
# 13141      2020-05-10                  25.0         1.500000
# 51         2020-03-01                                   1.018182
# 95         2020-03-01                                   0.000000
# 123        2020-03-01                                   0.000000
# 189        2020-03-01                                   0.000000
# ...                                                          ...
# 13132      2020-05-10                                   0.000000
# 13141      2020-05-10                                   0.000000
# 13155      2020-05-10                                   0.000000
# 13171      2020-05-10                                   0.000000
# 13248      2020-05-10                                   1.120000
#
# [25806 rows x 20 columns]

# %%
tscv = TimeSeriesSplit(
    n_splits=2)

# %%
score_models = {
    'lift':make_scorer(calc_lift, response_method='predict_proba'),
    'AUC':'roc_auc'
}

# %%
xgb_model = xgb.XGBClassifier(objective='binary:logistic')
xgb_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
test_params = {
    'max_depth':[1,2,4,6],
    'learning_rate':[0.1,0.2,0.3,0.4],
    'n_estimators':[20,40,80,120],
    'min_child_weight':[3,6,9,12]
}
test_params
# Out:
# {'max_depth': [1, 2, 4, 6],
#  'learning_rate': [0.1, 0.2, 0.3, 0.4],
#  'n_estimators': [20, 40, 80, 120],
#  'min_child_weight': [3, 6, 9, 12]}

# %%
#refit es con toda la informacion

gsearch = GridSearchCV(
    estimator=xgb_model, 
    n_jobs=-1,
    scoring=score_models,
    cv=tscv,
    verbose=1,
    return_train_score=False,
    param_grid=test_params,
    refit='AUC'
)

gsearch
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=2, test_size=None),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=Non...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [1, 2, 4, 6],
#                          'min_child_weight': [3, 6, 9, 12],
#                          'n_estimators': [20, 40, 80, 120]},
#              refit='AUC',
#              scoring={'AUC': 'roc_auc',
#                       'lift': make_scorer(calc_lift, response_method='predict_proba')},
#              verbose=1)

# %%
gsearch.fit(X,y)
# Out:
# Fitting 2 folds for each of 256 candidates, totalling 512 fits
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=2, test_size=None),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=Non...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.2, 0.3, 0.4],
#                          'max_depth': [1, 2, 4, 6],
#                          'min_child_weight': [3, 6, 9, 12],
#                          'n_estimators': [20, 40, 80, 120]},
#              refit='AUC',
#              scoring={'AUC': 'roc_auc',
#                       'lift': make_scorer(calc_lift, response_method='predict_proba')},
#              verbose=1)

# %%
df = pd.DataFrame(gsearch.cv_results_)
df.sort_values(by='mean_test_AUC', ascending=False, inplace=True)

# %%
df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 199       0.072871      0.020963         0.019811        0.001892
# 195       0.074125      0.017736         0.018174        0.000167
# 31        0.087890      0.024354         0.019023        0.000710
# 203       0.073248      0.020860         0.017635        0.000512
# 206       0.058424      0.017609         0.021867        0.001410
# ..             ...           ...              ...             ...
# 255       0.146871      0.035688         0.023236        0.000629
# 241       0.098716      0.014315         0.025233        0.002925
# 243       0.224241      0.055278         0.033710        0.005023
# 246       0.139800      0.039229         0.036241        0.008679
# 247       0.222867      0.055401         0.029774        0.000828
#
#      param_learning_rate  param_max_depth  param_min_child_weight  \
# 199                  0.4                1                       6
# 195                  0.4                1                       3
# 31                   0.1                2                      12
# 203                  0.4                1                       9
# 206                  0.4                1                      12
# ..                   ...              ...                     ...
# 255                  0.4                6                      12
# 241                  0.4                6                       3
# 243                  0.4                6                       3
# 246                  0.4                6                       6
# 247                  0.4                6                       6
#
#      param_n_estimators                                             params  \
# 199                 120  {'learning_rate': 0.4, 'max_depth': 1, 'min_ch...
# 195                 120  {'learning_rate': 0.4, 'max_depth': 1, 'min_ch...
# 31                  120  {'learning_rate': 0.1, 'max_depth': 2, 'min_ch...
# 203                 120  {'learning_rate': 0.4, 'max_depth': 1, 'min_ch...
# 206                  80  {'learning_rate': 0.4, 'max_depth': 1, 'min_ch...
# ..                  ...                                                ...
# 255                 120  {'learning_rate': 0.4, 'max_depth': 6, 'min_ch...
# 241                  40  {'learning_rate': 0.4, 'max_depth': 6, 'min_ch...
# 243                 120  {'learning_rate': 0.4, 'max_depth': 6, 'min_ch...
# 246                  80  {'learning_rate': 0.4, 'max_depth': 6, 'min_ch...
# 247                 120  {'learning_rate': 0.4, 'max_depth': 6, 'min_ch...
#
#      split0_test_lift  split1_test_lift  mean_test_lift  std_test_lift  \
# 199          3.458251          3.847048        3.652650       0.194399
# 195          3.351843          3.770107        3.560975       0.209132
# 31           3.671066          4.077871        3.874469       0.203402
# 203          3.458251          3.847048        3.652650       0.194399
# 206          3.511455          3.923989        3.717722       0.206267
# ..                ...               ...             ...            ...
# 255          2.660193          3.077639        2.868916       0.208723
# 241          2.873008          3.000698        2.936853       0.063845
# 243          2.500581          2.846816        2.673699       0.173117
# 246          2.660193          2.846816        2.753504       0.093311
# 247          2.713397          2.923757        2.818577       0.105180
#
#      rank_test_lift  split0_test_AUC  split1_test_AUC  mean_test_AUC  \
# 199              72         0.713745         0.725503       0.719624
# 195             121         0.710526         0.727320       0.718923
# 31                1         0.712320         0.724778       0.718549
# 203              72         0.714314         0.722764       0.718539
# 206              45         0.716278         0.720411       0.718345
# ..              ...              ...              ...            ...
# 255             249         0.648477         0.649565       0.649021
# 241             244         0.630804         0.661251       0.646027
# 243             256         0.635629         0.653808       0.644719
# 246             255         0.644620         0.639146       0.641883
# 247             251         0.645376         0.629918       0.637647
#
#      std_test_AUC  rank_test_AUC
# 199      0.005879              1
# 195      0.008397              2
# 31       0.006229              3
# 203      0.004225              4
# 206      0.002066              5
# ..            ...            ...
# 255      0.000544            252
# 241      0.015223            253
# 243      0.009089            254
# 246      0.002737            255
# 247      0.007729            256
#
# [256 rows x 19 columns]

# %%
df.to_csv('crossval_xgb.csv', index=False)

# %%
gsearch.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.4, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=1,
#               max_leaves=None, min_child_weight=6, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=120,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
with open('xgb_model.pkl', 'wb') as fid:
    pickle.dump(gsearch.best_estimator_, fid)

# %%
0.712850
# Out:
# 0.71285

# %%
0.714576
# Out:
# 0.714576
